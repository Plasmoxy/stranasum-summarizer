# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../datasets_big/wikihowSep.csv')

# %%
df
# Out:
#                                                   overview  \
# 0         So you're a new or aspiring artist and your c...
# 1         If you want to be well-read, then, in the wor...
# 2         So you're a new or aspiring artist and your c...
# 3         So you're a new or aspiring artist and your c...
# 4         So you're a new or aspiring artist and your c...
# ...                                                    ...
# 1585690   Before digital and photographic technology, i...
# 1585691   Before digital and photographic technology, i...
# 1585692   Before digital and photographic technology, i...
# 1585693   Before digital and photographic technology, i...
# 1585694   Before digital and photographic technology, i...
#
#                                                   headline  \
# 0                                   \nSell yourself first.
# 1                         \nRead the classics before 1600.
# 2                        \nJoin online artist communities.
# ...

# %%
l = df.iloc[100015]
print(l.overview, '\n---\n', l.headline)
# Out:
#  When exercising, you will want to keep track of your progress to see the level of improvement in each exercise. The best way to keep track is to learn how to make a fitness calendar to help your fitness level reach an all-time high!
# ---
#
# Color your chart any color by clicking in a box and going to FORMAT, BORDERS AND SHADING, SHADING, and then pick a color of your choice and click add.
